# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN,Dense

# %%
text="This is Computer Science Department.I'm specializing in AI "
chars=sorted(list(set(text)))
 
char_to_index={char:i for i, char in enumerate(chars)}
index_to_char={i: char for i, char in enumerate(chars)}

# %%
seq_length=3
sequences=[]
labels=[]

for i in range(len(text)-seq_length):
    seq=text[i:i+seq_length]
    label=text[i+seq_length]
    sequences.append([char_to_index[char] for char in seq])
    labels.append(char_to_index[label])

X=np.array(sequences)
y=np.array(labels)

# %%
X_one_hot=tf.one_hot(X,len(chars))
y_one_hot=tf.one_hot(y,len(chars))

# %%
model = Sequential()
model.add(SimpleRNN(50, input_shape=(seq_length, len(chars)), activation='relu'))
model.add(Dense(len(chars), activation='softmax'))
# Out:
# C:\anaconda\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])

# %%
model.fit(X_one_hot,y_one_hot,epochs=100)
# Out:
# Epoch 1/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.0461 - loss: 3.2521
# Epoch 2/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.0565 - loss: 3.2281
# Epoch 3/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.0670 - loss: 3.2025
# Epoch 4/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.0565 - loss: 3.1922
# Epoch 5/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.0685 - loss: 3.1717
# Epoch 6/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.0789 - loss: 3.1587
# Epoch 7/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.0699 - loss: 3.1445
# Epoch 8/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.1027 - loss: 3.1304
# Epoch 9/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.1458 - loss: 3.1070
# Epoch 10/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.1905 - loss: 3.0970
# Epoch 11/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.1592 - loss: 3.0885
# Epoch 12/100
# ...

# %%
start_seq="This is C"
generated_text=start_seq

for i in range(50):
    x=np.array([[char_to_index[char] for char in generated_text[-seq_length:]]])
    x_one_hot=tf.one_hot(x,len(chars))
    prediction=model.predict(x_one_hot)
    next_index=np.argmax(prediction)
    next_char=index_to_char[next_index]
    generated_text+=next_char

print("Generated Text:")
print(generated_text)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 436ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# ...

# %%
start_seq="This is Aneela"
generated_text=start_seq

for i in range(50):
    x=np.array([[char_to_index[char] for char in generated_text[-seq_length:]]])
    x_one_hot=tf.one_hot(x,len(chars))
    prediction=model.predict(x_one_hot)
    next_index=np.argmax(prediction)
    next_char=index_to_char[next_index]
    generated_text+=next_char

print("Generated Text:")
print(generated_text)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# ...

# %%
model.fit(X_one_hot,y_one_hot,epochs=50) #epoches == 50

start_seq="This is C"
generated_text=start_seq

for i in range(50):
    x=np.array([[char_to_index[char] for char in generated_text[-seq_length:]]])
    x_one_hot=tf.one_hot(x,len(chars))
    prediction=model.predict(x_one_hot)
    next_index=np.argmax(prediction)
    next_char=index_to_char[next_index]
    generated_text+=next_char

print("Generated Text:")
print(generated_text)
# Out:
# Epoch 1/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9881 - loss: 0.3311
# Epoch 2/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.9777 - loss: 0.3354
# Epoch 3/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9777 - loss: 0.3252
# Epoch 4/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9777 - loss: 0.3219
# Epoch 5/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.9881 - loss: 0.2925
# Epoch 6/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9777 - loss: 0.2943
# Epoch 7/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9777 - loss: 0.2753
# Epoch 8/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9881 - loss: 0.2611
# Epoch 9/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9881 - loss: 0.2458
# Epoch 10/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9777 - loss: 0.2600
# Epoch 11/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9881 - loss: 0.2447
# Epoch 12/50
# ...

# %%
model.fit(X_one_hot,y_one_hot,epochs=50) #epoches == 50

start_seq="This is aneela"
generated_text=start_seq

for i in range(50):
    x=np.array([[char_to_index[char] for char in generated_text[-seq_length:]]])
    x_one_hot=tf.one_hot(x,len(chars))
    prediction=model.predict(x_one_hot)
    next_index=np.argmax(prediction)
    next_char=index_to_char[next_index]
    generated_text+=next_char

print("Generated Text:")
print(generated_text)
# Out:
# Epoch 1/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9881 - loss: 0.0989
# Epoch 2/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9777 - loss: 0.1144
# Epoch 3/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9777 - loss: 0.1100
# Epoch 4/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.9777 - loss: 0.1065
# Epoch 5/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.9881 - loss: 0.0964
# Epoch 6/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9777 - loss: 0.1089
# Epoch 7/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9777 - loss: 0.1015
# Epoch 8/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9881 - loss: 0.0897
# Epoch 9/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.9881 - loss: 0.0907
# Epoch 10/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.9777 - loss: 0.0985
# Epoch 11/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9881 - loss: 0.0832
# Epoch 12/50
# ...

# %%
model.fit(X_one_hot,y_one_hot,epochs=50) #epoches == 50

start_seq="This is c"
generated_text=start_seq

for i in range(50):
    x=np.array([[char_to_index[char] for char in generated_text[-seq_length:]]])
    x_one_hot=tf.one_hot(x,len(chars))
    prediction=model.predict(x_one_hot)
    next_index=np.argmax(prediction)
    next_char=index_to_char[next_index]
    generated_text+=next_char

print("Generated Text:")
print(generated_text)
# Out:
# Epoch 1/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.9777 - loss: 0.0673
# Epoch 2/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9777 - loss: 0.0737
# Epoch 3/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9777 - loss: 0.0655
# Epoch 4/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9777 - loss: 0.0721
# Epoch 5/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9881 - loss: 0.0590
# Epoch 6/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9881 - loss: 0.0642
# Epoch 7/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9777 - loss: 0.0700
# Epoch 8/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9881 - loss: 0.0623
# Epoch 9/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9881 - loss: 0.0573
# Epoch 10/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9777 - loss: 0.0696
# Epoch 11/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9881 - loss: 0.0567
# Epoch 12/50
# ...

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Bidirectional
from tensorflow.keras.optimizers import Adam

# Step 1: Read Text from a File
file_path = "Sora.txt" 
with open(file_path, "r", encoding="utf-8") as file:
    text = file.read()

# Step 2: Preprocess Text
chars = sorted(list(set(text)))
char_to_index = {char: i for i, char in enumerate(chars)}
index_to_char = {i: char for i, char in enumerate(chars)}

# Step 3: Create Sequences and Labels
seq_length = 5  # Increased sequence length for better learning
sequences = []
labels = []

for i in range(len(text) - seq_length):
    seq = text[i:i + seq_length]
    label = text[i + seq_length]
    sequences.append([char_to_index[char] for char in seq])
    labels.append(char_to_index[label])

# Convert to NumPy Arrays
X = np.array(sequences)
y = np.array(labels)

# One-Hot Encoding for Training
X_one_hot = tf.one_hot(X, len(chars))
y_one_hot = tf.one_hot(y, len(chars))

# Step 4: Build an Optimized RNN Model with LSTM
model = Sequential()
model.add(Bidirectional(LSTM(128, return_sequences=True, activation='tanh'), input_shape=(seq_length, len(chars))))
model.add(Dropout(0.3))
model.add(Bidirectional(LSTM(64, activation='tanh')))
model.add(Dropout(0.2))
model.add(Dense(len(chars), activation='softmax'))

# Compile Model
optimizer = Adam(learning_rate=0.000)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# Train the Model
history = model.fit(X_one_hot, y_one_hot, epochs=100, batch_size=16, verbose=1)

# Evaluate Model
train_loss, train_acc = model.evaluate(X_one_hot, y_one_hot, verbose=0)
print(f"Final Train Accuracy: {train_acc * 100:.2f}%")

# Step 5: Generate New Text
start_seq = text[:seq_length]  # Start with the first few characters of the file
generated_text = start_seq

for i in range(100):
    x = np.array([[char_to_index[char] for char in generated_text[-seq_length:]]])
    x_one_hot = tf.one_hot(x, len(chars))
    prediction = model.predict(x_one_hot)
    next_index = np.argmax(prediction)
    next_char = index_to_char[next_index]
    generated_text += next_char

print("Generated Text:")
print(generated_text)
# Out:
# C:\anaconda\Lib\site-packages\keras\src\layers\rnn\bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 25s 19ms/step - accuracy: 0.0206 - loss: 4.2748
# Epoch 2/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.0230 - loss: 4.2749
# Epoch 3/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - accuracy: 0.0195 - loss: 4.2747
# Epoch 4/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.0220 - loss: 4.2749
# Epoch 5/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - accuracy: 0.0170 - loss: 4.2750
# Epoch 6/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 8s 17ms/step - accuracy: 0.0238 - loss: 4.2750
# Epoch 7/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - accuracy: 0.0235 - loss: 4.2750
# Epoch 8/100
# ...

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense

file_path = "Sora.txt" 
with open(file_path, "r", encoding="utf-8") as file:
    text = file.read()
chars = sorted(list(set(text)))
char_to_index = {char: i for i, char in enumerate(chars)}
index_to_char = {i: char for i, char in enumerate(chars)}

seq_length = 3
sequences = []
labels = []

for i in range(len(text) - seq_length):
    seq = text[i:i + seq_length]
    label = text[i + seq_length]
    sequences.append([char_to_index[char] for char in seq])
    labels.append(char_to_index[label])

X = np.array(sequences)
y = np.array(labels)

X_one_hot = tf.one_hot(X, len(chars))
y_one_hot = tf.one_hot(y, len(chars))

model = Sequential()
model.add(SimpleRNN(50, input_shape=(seq_length, len(chars)), activation='relu'))
model.add(Dense(len(chars), activation='softmax'))

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.fit(X_one_hot, y_one_hot, epochs=100)

start_seq = "This is G"
generated_text = start_seq

for i in range(50):
    x = np.array([[char_to_index[char] for char in generated_text[-seq_length:]]])
    x_one_hot = tf.one_hot(x, len(chars))
    prediction = model.predict(x_one_hot)
    next_index = np.argmax(prediction)
    next_char = index_to_char[next_index]
    generated_text += next_char

print("Generated Text:")
print(generated_text)
# Out:
# Epoch 1/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.1119 - loss: 3.6750
# Epoch 2/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1945 - loss: 2.9062
# Epoch 3/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.2637 - loss: 2.7434
# Epoch 4/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.2905 - loss: 2.6152
# Epoch 5/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3254 - loss: 2.4724
# Epoch 6/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3350 - loss: 2.4098
# Epoch 7/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3719 - loss: 2.2994
# Epoch 8/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3701 - loss: 2.2730
# Epoch 9/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3774 - loss: 2.2479
# Epoch 10/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3902 - loss: 2.1843
# Epoch 11/100
# ...

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Bidirectional, Dense, Dropout
from tensorflow.keras.callbacks import ReduceLROnPlateau
#import PyPDF2

file_path = "Sora.txt" 
with open(file_path, "r", encoding="utf-8") as file:
    text = file.read()
chars = sorted(list(set(text)))

# Ensure text is extracted
if not text.strip():
    raise ValueError("No text found in the PDF. Please check the file.")

# Create character mappings
chars = sorted(set(text))  # Unique characters
char_to_index = {char: i for i, char in enumerate(chars)}
index_to_char = {i: char for i, char in enumerate(chars)}

# Sequence length
seq_length = 5  
sequences = []
labels = []

# Create sequences and labels
for i in range(len(text) - seq_length):
    seq = text[i:i + seq_length]
    label = text[i + seq_length]
    sequences.append([char_to_index[char] for char in seq])
    labels.append(char_to_index[label])

# Convert to NumPy arrays
X = np.array(sequences)
y = np.array(labels)

# One-hot encoding
X_one_hot = tf.one_hot(X, len(chars))
y_one_hot = tf.one_hot(y, len(chars))

# Build the model with Bidirectional LSTM
model = Sequential()
model.add(Bidirectional(LSTM(128, return_sequences=True, input_shape=(seq_length, len(chars)), activation='relu')))
model.add(Dropout(0.3))  
model.add(Bidirectional(LSTM(128, activation='relu')))
model.add(Dense(len(chars), activation='softmax'))

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Learning Rate Scheduler
lr_scheduler = ReduceLROnPlateau(monitor="loss", factor=0.5, patience=5, min_lr=1e-6)

# Train the model
model.fit(X_one_hot, y_one_hot, epochs=100, batch_size=32, callbacks=[lr_scheduler], verbose=1)

# Evaluate and print the final accuracy
loss, accuracy = model.evaluate(X_one_hot, y_one_hot)
print(f"\nFinal Accuracy: {accuracy * 100:.2f}%")

# Function to generate text with temperature sampling
def sample_with_temperature(preds, temperature=0.5):
    preds = np.asarray(preds).astype("float64")
    preds = np.log(preds + 1e-7) / temperature  
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)  
    return np.random.choice(len(preds), p=preds)  

# Start sequence for text generation
start_seq = text[:5]  # Use the first 5 characters of the training text
generated_text = start_seq

# Generate 100 characters
for i in range(100):
    x = np.array([[char_to_index.get(char, char_to_index[' ']) for char in generated_text[-seq_length:]]])
    x_one_hot = tf.one_hot(x, len(chars))

    prediction = model.predict(x_one_hot, verbose=0)
    next_index = sample_with_temperature(prediction[0], temperature=0.5)  
    next_char = index_to_char[next_index]

    generated_text += next_char

# Print the generated text
print("\nGenerated Text:")
print(generated_text)
# Out:
# Epoch 1/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 18s 22ms/step - accuracy: 0.1360 - loss: 3.4590 - learning_rate: 0.0010
# Epoch 2/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.1768 - loss: 2.9919 - learning_rate: 0.0010
# Epoch 3/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.2537 - loss: 2.6235 - learning_rate: 0.0010
# Epoch 4/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.2984 - loss: 2.4350 - learning_rate: 0.0010
# Epoch 5/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.3290 - loss: 2.3460 - learning_rate: 0.0010
# Epoch 6/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.3371 - loss: 2.2546 - learning_rate: 0.0010
# Epoch 7/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.3602 - loss: 2.1462 - learning_rate: 0.0010
# Epoch 8/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - accuracy: 0.4058 - loss: 2.0283 - learning_rate: 0.0010
# Epoch 9/100
# ...

# %%
# Importing Libraries
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Bidirectional
from tensorflow.keras.optimizers import Adam

# Define the Input Text and Character Set
file_path = "Sora.txt" 
with open(file_path, "r", encoding="utf-8") as file:
    text = file.read()
char_to_index = {char: i for i, char in enumerate(chars)}
index_to_char = {i: char for i, char in enumerate(chars)}

# Create Sequences and Labels
seq_length = 5  # Increased sequence length for better learning
sequences = []
labels = []

for i in range(len(text) - seq_length):
    seq = text[i:i + seq_length]
    label = text[i + seq_length]
    sequences.append([char_to_index[char] for char in seq])
    labels.append(char_to_index[label])

# Convert to NumPy Arrays
X = np.array(sequences)
y = np.array(labels)

# One-Hot Encoding for Training
X_one_hot = tf.one_hot(X, len(chars))
y_one_hot = tf.one_hot(y, len(chars))

# Build an Optimized RNN Model with LSTM
model = Sequential()

# Bidirectional LSTM Layer (Better Memory Retention)
model.add(Bidirectional(LSTM(128, return_sequences=True, activation='tanh'), input_shape=(seq_length, len(chars))))
model.add(Dropout(0.3))  # Dropout to prevent overfitting

# Second LSTM Layer
model.add(Bidirectional(LSTM(64, activation='tanh')))
model.add(Dropout(0.2))

# Output Layer (Softmax for Multiclass Classification)
model.add(Dense(len(chars), activation='softmax'))

# Compile Model with Optimized Learning Rate
optimizer = Adam(learning_rate=0.0005)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# Train the Model with More Epochs
history = model.fit(X_one_hot, y_one_hot, epochs=200, batch_size=16, verbose=1)

# Evaluate Model
train_loss, train_acc = model.evaluate(X_one_hot, y_one_hot, verbose=0)
print(f"Final Train Accuracy: {train_acc * 100:.2f}%")

# Generate New Text
start_seq = "This is U"
generated_text = start_seq

for i in range(100):
    x = np.array([[char_to_index[char] for char in generated_text[-seq_length:]]])
    x_one_hot = tf.one_hot(x, len(chars))
    prediction = model.predict(x_one_hot)
    next_index = np.argmax(prediction)
    next_char = index_to_char[next_index]
    generated_text += next_char

print("Generated Text:")
print(generated_text)
# Out:
# Epoch 1/200
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 19s 14ms/step - accuracy: 0.1355 - loss: 3.5202
# Epoch 2/200
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.2136 - loss: 2.9053
# Epoch 3/200
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - accuracy: 0.2603 - loss: 2.6089
# Epoch 4/200
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.3022 - loss: 2.4771
# Epoch 5/200
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.3349 - loss: 2.3494
# Epoch 6/200
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.3290 - loss: 2.2961
# Epoch 7/200
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.3463 - loss: 2.2612
# Epoch 8/200
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - accuracy: 0.3690 - loss: 2.1690
# Epoch 9/200
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.3836 - loss: 2.1293
# Epoch 10/200
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.4020 - loss: 2.0526
# Epoch 11/200
# ...

# %%
# Importing Libraries
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Bidirectional
from tensorflow.keras.optimizers import Adam

# Define the Input Text and Character Set
file_path = "Sora.txt" 
with open(file_path, "r", encoding="utf-8") as file:
    text = file.read()
char_to_index = {char: i for i, char in enumerate(chars)}
index_to_char = {i: char for i, char in enumerate(chars)}

# Create Sequences and Labels
seq_length = 5  # Increased sequence length for better learning
sequences = []
labels = []

for i in range(len(text) - seq_length):
    seq = text[i:i + seq_length]
    label = text[i + seq_length]
    sequences.append([char_to_index[char] for char in seq])
    labels.append(char_to_index[label])

# Convert to NumPy Arrays
X = np.array(sequences)
y = np.array(labels)

# One-Hot Encoding for Training
X_one_hot = tf.one_hot(X, len(chars))
y_one_hot = tf.one_hot(y, len(chars))

# Build an Optimized RNN Model with LSTM
model = Sequential()

# Bidirectional LSTM Layer (Better Memory Retention)
model.add(Bidirectional(LSTM(128, return_sequences=True, activation='tanh'), input_shape=(seq_length, len(chars))))
model.add(Dropout(0.3))  # Dropout to prevent overfitting

# Second LSTM Layer
model.add(Bidirectional(LSTM(64, activation='tanh')))
model.add(Dropout(0.2))

# Output Layer (Softmax for Multiclass Classification)
model.add(Dense(len(chars), activation='softmax'))

# Compile Model with Optimized Learning Rate
optimizer = Adam(learning_rate=0.0005)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# Train the Model with More Epochs
history = model.fit(X_one_hot, y_one_hot, epochs=100, batch_size=16, verbose=1)

# Evaluate Model
train_loss, train_acc = model.evaluate(X_one_hot, y_one_hot, verbose=0)
print(f"Final Train Accuracy: {train_acc * 100:.2f}%")

# Generate New Text
start_seq = "I"
generated_text = start_seq

for i in range(100):
    x = np.array([[char_to_index[char] for char in generated_text[-seq_length:]]])
    x_one_hot = tf.one_hot(x, len(chars))
    prediction = model.predict(x_one_hot)
    next_index = np.argmax(prediction)
    next_char = index_to_char[next_index]
    generated_text += next_char

print("Generated Text:")
print(generated_text)
# Out:
# Epoch 1/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 20s 11ms/step - accuracy: 0.1354 - loss: 3.5089
# Epoch 2/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.2179 - loss: 2.8452
# Epoch 3/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - accuracy: 0.2700 - loss: 2.5842
# Epoch 4/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.2965 - loss: 2.4788
# Epoch 5/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - accuracy: 0.3106 - loss: 2.3918
# Epoch 6/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.3342 - loss: 2.3028
# Epoch 7/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.3621 - loss: 2.1800
# Epoch 8/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - accuracy: 0.3591 - loss: 2.1867
# Epoch 9/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.3849 - loss: 2.1100
# Epoch 10/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.4072 - loss: 2.0242
# Epoch 11/100
# ...
